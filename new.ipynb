# %%
import pandas as pd

# %%
import numpy as np
arr=np.array([2,4,5])
print(arr)
# Out:
# [2 4 5]

# %%
df=pd.read_csv('main.csv')
df
# Out:
#     Ambuja cement Ltd     product name  Quantity  Unit price  \
# 0   Ambuja cement Ltd    AMBUJA KAWACH       200         360
# 1   Ambuja cement Ltd    AMBUJA KAWACH       500         400
# 2   Ambuja cement Ltd  AMBUJA COMPOCEM        80         350
# 3   Ambuja cement Ltd    AMBUJA KAWACH       300         360
# 4   Ambuja cement Ltd  AMBUJA COMPOCEM       200         340
# 5   Ambuja cement Ltd  AMBUJA COMPOCEM       400         340
# 6   Ambuja cement Ltd  AMBUJA COMPOCEM       100         400
# 7   Ambuja cement Ltd  AMBUJA COMPOCEM        50         370
# 8   Ambuja cement Ltd    AMBUJA KAWACH        30         395
# 9   Ambuja cement Ltd    AMBUJA KAWACH       120         375
# 10  Ambuja cement Ltd  AMBUJA COMPOCEM        50         380
# 11  Ambuja cement Ltd  AMBUJA COMPOCEM        60         380
# 12  Ambuja cement Ltd  AMBUJA COMPOCEM        60         380
# 13  Ambuja cement Ltd  AMBUJA COMPOCEM        70         380
#
# ...

# %%
carsels=pd.read_csv('cars.csv')
carsels
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White       150043.0      4   4000.0
# 1   Honda    Red        87899.0      4   5000.0
# 2  Toyota   Blue        73892.0      3   7000.0
# 3     BMW  Black        11179.0      5  22000.0
# 4  Nissan  White       213095.0      4   3500.0
# 5  Toyota  Green       109842.0      4   4500.0
# 6   Honda    red         8045.0      4   7500.0
# 7   Honda   Blue            NaN      4      NaN
# 8  Toyota  White        60000.0      4      NaN
# 9  Nissan  White        31600.0      4   9700.0

# %%
carsels['Price'].fillna(4200,inplace=True)
carsels
# Out:
# /tmp/ipykernel_2498/1951317307.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   carsels['Price'].fillna(4200,inplace=True)
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White       150043.0      4   4000.0
# 1   Honda    Red        87899.0      4   5000.0
# 2  Toyota   Blue        73892.0      3   7000.0
# 3     BMW  Black        11179.0      5  22000.0
# 4  Nissan  White       213095.0      4   3500.0
# 5  Toyota  Green       109842.0      4   4500.0
# ...

# %%
seat=pd.Series([4,4,5,6,4,7])
carsels['seats']=seat
carsels
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats
# 0  Toyota  White       150043.0      4   4000.0    4.0
# 1   Honda    Red        87899.0      4   5000.0    4.0
# 2  Toyota   Blue        73892.0      3   7000.0    5.0
# 3     BMW  Black        11179.0      5  22000.0    6.0
# 4  Nissan  White       213095.0      4   3500.0    4.0
# 5  Toyota  Green       109842.0      4   4500.0    7.0
# 6   Honda    red         8045.0      4   7500.0    NaN
# 7   Honda   Blue         2000.0      4   2000.0    NaN
# 8  Toyota  White        60000.0      4   2000.0    NaN
# 9  Nissan  White        31600.0      4   9700.0    NaN

# %%
carsels
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats
# 0  Toyota  White       150043.0      4   4000.0    4.0
# 1   Honda    Red        87899.0      4   5000.0    4.0
# 2  Toyota   Blue        73892.0      3   7000.0    5.0
# 3     BMW  Black        11179.0      5  22000.0    6.0
# 4  Nissan  White       213095.0      4   3500.0    4.0
# 5  Toyota  Green       109842.0      4   4500.0    7.0
# 6   Honda    red         8045.0      4   7500.0    NaN
# 7   Honda   Blue         2000.0      4   2000.0    NaN
# 8  Toyota  White        60000.0      4   2000.0    NaN
# 9  Nissan  White        31600.0      4   9700.0    NaN

# %%
carsels['seats'].fillna(carsels['seats'].mean())
# Out:
# 0    4.0
# 1    4.0
# 2    5.0
# 3    6.0
# 4    4.0
# 5    7.0
# 6    5.0
# 7    5.0
# 8    5.0
# 9    5.0
# Name: seats, dtype: float64

# %%
carsels
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats
# 0  Toyota  White       150043.0      4   4000.0    4.0
# 1   Honda    Red        87899.0      4   5000.0    4.0
# 2  Toyota   Blue        73892.0      3   7000.0    5.0
# 3     BMW  Black        11179.0      5  22000.0    6.0
# 4  Nissan  White       213095.0      4   3500.0    4.0
# 5  Toyota  Green       109842.0      4   4500.0    7.0
# 6   Honda    red         8045.0      4   7500.0    5.0
# 7   Honda   Blue         2000.0      4   2000.0    5.0
# 8  Toyota  White        60000.0      4   2000.0    5.0
# 9  Nissan  White        31600.0      4   9700.0    5.0

# %%
carsels.to_csv("updatecars.csv",index=False)
